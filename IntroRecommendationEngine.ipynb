# %% [markdown]
# <a href="https://colab.research.google.com/github/titaofdata/Week-10-Models-Used-in-Industries/blob/main/IntroRecommendationEngine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Recommendation Engines
# A recommendation system is a subclass of information filtering system that seeks to predict the “rating” or “preference” a user would give to an item.
#
# Practically speaking, this system provides you items or products based on your past purchases or interests.
#
# ### Types of making recommendation systems?
#
# - Content-based recommendation — based on product attributes
# - Collaborative filtering — based on similar users
#
# ### Content based recommendation:
#
# System use the knowledge of each product to recommend a new product.
#
# Example: If you are interested to watch a romantic movie, then the system would recommend you the list of movies in that genre.
#
# It works well if you have descriptive data available for the product you have to recommend.
#
# ### Collaborative filtering:
#
# System don’t have any knowledge about the product but it recommend only based on the user’s rating in the past.
#
# Example: Consider that you rated a list of movies. If you gave 4.5/5 for an horror movie and 1.5 for an adventure movie, then the system would recommend horror movies in the future.
#
# Reference: [link](https://medium.com/coinmonks/recommendation-engine-python-401c080c583e)
#
# Now let us move on to the steps for building a system.

# %% [markdown]
# ### Import Packages

# %%
import numpy as np
import pandas as pd
import os
from collections import defaultdict
import io

# %% [markdown]
# ### Install Surprise
# Surprise is python scikit building and analyzing recommender systems.

# %%
# !pip install surprise
# Out:
# Collecting surprise
#   Downloading surprise-0.1-py2.py3-none-any.whl (1.8 kB)
# Collecting scikit-surprise
#   Downloading scikit-surprise-1.1.1.tar.gz (11.8 MB)
# Requirement already satisfied: joblib>=0.11 in c:\programdata\anaconda3\lib\site-packages (from scikit-surprise->surprise) (0.14.1)
# Requirement already satisfied: numpy>=1.11.2 in c:\programdata\anaconda3\lib\site-packages (from scikit-surprise->surprise) (1.18.1)
# Requirement already satisfied: scipy>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-surprise->surprise) (1.4.1)
# Requirement already satisfied: six>=1.10.0 in c:\users\admin2\appdata\roaming\python\python37\site-packages (from scikit-surprise->surprise) (1.15.0)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (setup.py): started
#   Building wheel for scikit-surprise (setup.py): finished with status 'done'
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.1-cp37-cp37m-win_amd64.whl size=771642 sha256=37f967def20b0b9296a89cd18c5f178258e62f3beb9a3dbb12bb63eef570403e
#   Stored in directory: c:\users\admin2\appdata\local\pip\cache\wheels\76\44\74\b498c42be47b2406bd27994e16c5188e337c657025ab400c1c
# Successfully built scikit-surprise
# Installing collected packages: scikit-surprise, surprise
# Successfully installed scikit-surprise-1.1.1 surprise-0.1

# %%
from surprise import SVD
from surprise import Dataset
from surprise.model_selection import cross_validate
from surprise import Reader
from surprise import get_dataset_dir
from surprise.model_selection import KFold

# %% [markdown]
# ### Load Dataset
# GroupLens Research has collected and made available rating data sets from the MovieLens [website](http://movielens.org). The data sets were collected over various periods of time, depending on the size of the set.

# %%
data = Dataset.load_builtin('ml-100k')
# Out:
# Dataset ml-100k could not be found. Do you want to download it? [Y/n] Y
# Trying to download dataset from http://files.grouplens.org/datasets/movielens/ml-100k.zip...
# Done! Dataset ml-100k has been saved to C:\Users\admin2/.surprise_data/ml-100k

# %%
file_path = os.path.expanduser('~/.surprise_data/ml-100k/ml-100k/u.data')
read_data = pd.read_csv(file_path, '\t', names = ['user', 'item', 'rating', 'timestamp'])

read_data.head()
# Out:
#    user  item  rating  timestamp
# 0   196   242       3  881250949
# 1   186   302       3  891717742
# 2    22   377       1  878887116
# 3   244    51       2  880606923
# 4   166   346       1  886397596

# %%
# Use the famous SVD algorithm.
algo = SVD()

# %%
# Run 5-fold cross-validation and print results.
cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9386  0.9354  0.9376  0.9448  0.9265  0.9366  0.0059
# MAE (testset)     0.7396  0.7362  0.7368  0.7477  0.7311  0.7383  0.0054
# Fit time          5.51    5.44    5.64    5.64    5.47    5.54    0.08
# Test time         0.23    0.15    0.16    0.21    0.15    0.18    0.03
# {'test_rmse': array([0.93858198, 0.93539632, 0.93764301, 0.94482162, 0.92651513]),
#  'test_mae': array([0.73958617, 0.73622615, 0.73684406, 0.74766993, 0.73108726]),
#  'fit_time': (5.513714551925659,
#   5.442480564117432,
#   5.63617205619812,
#   5.637964963912964,
#   5.473106861114502),
#  'test_time': (0.22664284706115723,
#   0.15340828895568848,
#   0.15746164321899414,
#   0.2065443992614746,
#   0.1534442901611328)}

# %% [markdown]
# ### Actual Movie Name Mapping

# %%
def read_item_names():
    """Read the u.item file from MovieLens 100-k dataset and return two
    mappings to convert raw ids into movie names and movie names into raw ids.
    """

    file_name = get_dataset_dir() + '/ml-100k/ml-100k/u.item'
    rid_to_name = {}
    name_to_rid = {}
    with io.open(file_name, 'r', encoding='ISO-8859-1') as f:
        for line in f:
            line = line.split('|')
            rid_to_name[line[0]] = line[1]
            name_to_rid[line[1]] = line[0]

    return rid_to_name, name_to_rid

# %%
rid_to_name, name_to_rid = read_item_names()

# %% [markdown]
# ### Get Watched Movies by a Specific User

# %%
user_trial = "6"

# %%
[rid_to_name[str(i)] for i in read_data.groupby('user')['item'].apply(list)[int(user_trial)]][:10]
# Out:
# ['Remains of the Day, The (1993)',
#  'Postino, Il (1994)',
#  'Silence of the Lambs, The (1991)',
#  'Secret of Roan Inish, The (1994)',
#  'In & Out (1997)',
#  'Contact (1997)',
#  'Forrest Gump (1994)',
#  'Manhattan (1979)',
#  'Taxi Driver (1976)',
#  'East of Eden (1955)']

# %% [markdown]
# ### Get Top *N* Recommendations per User

# %%
def get_top_n(predictions, n=10):
    '''Return the top-N recommendation for each user from a set of predictions.

    Args:
        predictions(list of Prediction objects): The list of predictions, as
            returned by the test method of an algorithm.
        n(int): The number of recommendation to output for each user. Default
            is 10.

    Returns:
    A dict where keys are user (raw) ids and values are lists of tuples:
        [(raw item id, rating estimation), ...] of size n.
    '''

    # First map the predictions to each user.
    top_n = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))

    # Then sort the predictions for each user and retrieve the k highest ones.
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]

    return top_n

# %%
trainset = data.build_full_trainset()

algo.fit(trainset)

# Than predict ratings for all pairs (u, i) that are NOT in the training set.
testset = trainset.build_anti_testset()

predictions = algo.test(testset)

top_n = get_top_n(predictions, n=10)

# %%
predictions
# Out:
# [Prediction(uid='196', iid='302', r_ui=3.52986, est=4.212118037212345, details={'was_impossible': False}),
#  Prediction(uid='196', iid='377', r_ui=3.52986, est=2.9200336487943312, details={'was_impossible': False}),
#  Prediction(uid='196', iid='51', r_ui=3.52986, est=3.47372703437081, details={'was_impossible': False}),
#  Prediction(uid='196', iid='346', r_ui=3.52986, est=3.5638539529932234, details={'was_impossible': False}),
#  Prediction(uid='196', iid='474', r_ui=3.52986, est=4.195122809708869, details={'was_impossible': False}),
#  Prediction(uid='196', iid='265', r_ui=3.52986, est=3.6233183024499116, details={'was_impossible': False}),
#  Prediction(uid='196', iid='465', r_ui=3.52986, est=3.695863019993495, details={'was_impossible': False}),
#  Prediction(uid='196', iid='451', r_ui=3.52986, est=3.7121047006943337, details={'was_impossible': False}),
#  Prediction(uid='196', iid='86', r_ui=3.52986, est=4.020322975587146, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1014', r_ui=3.52986, est=3.066075557919996, details={'was_impossible': False}),
#  Prediction(uid='196', iid='222', r_ui=3.52986, est=3.348112401919575, details={'was_impossible': False}),
#  Prediction(uid='196', iid='40', r_ui=3.52986, est=3.1800223094898556, details={'was_impossible': False}),
#  Prediction(uid='196', iid='29', r_ui=3.52986, est=2.8556357551044456, details={'was_impossible': False}),
#  Prediction(uid='196', iid='785', r_ui=3.52986, est=3.277949399606028, details={'was_impossible': False}),
#  Prediction(uid='196', iid='387', r_ui=3.52986, est=3.6227014304073464, details={'was_impossible': False}),
#  Prediction(uid='196', iid='274', r_ui=3.52986, est=3.4647711131399896, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1042', r_ui=3.52986, est=3.328650665672361, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1184', r_ui=3.52986, est=3.1114991067831808, details={'was_impossible': False}),
#  Prediction(uid='196', iid='392', r_ui=3.52986, est=3.498939724619076, details={'was_impossible': False}),
#  Prediction(uid='196', iid='486', r_ui=3.52986, est=3.725695102706409, details={'was_impossible': False}),
#  Prediction(uid='196', iid='144', r_ui=3.52986, est=3.474114049294265, details={'was_impossible': False}),
#  Prediction(uid='196', iid='118', r_ui=3.52986, est=3.1924303328599444, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1', r_ui=3.52986, est=3.539769135659559, details={'was_impossible': False}),
#  Prediction(uid='196', iid='546', r_ui=3.52986, est=2.9183681053417563, details={'was_impossible': False}),
#  Prediction(uid='196', iid='95', r_ui=3.52986, est=3.715834779200399, details={'was_impossible': False}),
#  Prediction(uid='196', iid='768', r_ui=3.52986, est=3.1491609716490214, details={'was_impossible': False}),
#  Prediction(uid='196', iid='277', r_ui=3.52986, est=3.361515916459248, details={'was_impossible': False}),
#  Prediction(uid='196', iid='234', r_ui=3.52986, est=3.6970495795081977, details={'was_impossible': False}),
#  Prediction(uid='196', iid='246', r_ui=3.52986, est=3.8587076431258676, details={'was_impossible': False}),
#  Prediction(uid='196', iid='98', r_ui=3.52986, est=4.13559128195983, details={'was_impossible': False}),
#  Prediction(uid='196', iid='193', r_ui=3.52986, est=3.7440490448736217, details={'was_impossible': False}),
#  Prediction(uid='196', iid='88', r_ui=3.52986, est=3.300640614462442, details={'was_impossible': False}),
#  Prediction(uid='196', iid='194', r_ui=3.52986, est=3.6675525600861945, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1081', r_ui=3.52986, est=3.402344134824494, details={'was_impossible': False}),
#  Prediction(uid='196', iid='603', r_ui=3.52986, est=4.440533906047032, details={'was_impossible': False}),
#  Prediction(uid='196', iid='796', r_ui=3.52986, est=3.1496924168036293, details={'was_impossible': False}),
#  Prediction(uid='196', iid='32', r_ui=3.52986, est=3.869002218026133, details={'was_impossible': False}),
#  Prediction(uid='196', iid='16', r_ui=3.52986, est=3.398267271072662, details={'was_impossible': False}),
#  Prediction(uid='196', iid='304', r_ui=3.52986, est=3.561625362179417, details={'was_impossible': False}),
#  Prediction(uid='196', iid='979', r_ui=3.52986, est=3.3994724177757187, details={'was_impossible': False}),
#  Prediction(uid='196', iid='564', r_ui=3.52986, est=2.4879074603037856, details={'was_impossible': False}),
#  Prediction(uid='196', iid='327', r_ui=3.52986, est=3.4124549350503175, details={'was_impossible': False}),
#  Prediction(uid='196', iid='201', r_ui=3.52986, est=3.644192165485766, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1137', r_ui=3.52986, est=4.172165099664094, details={'was_impossible': False}),
#  Prediction(uid='196', iid='241', r_ui=3.52986, est=3.825562734552264, details={'was_impossible': False}),
#  Prediction(uid='196', iid='4', r_ui=3.52986, est=3.2024571234316395, details={'was_impossible': False}),
#  Prediction(uid='196', iid='332', r_ui=3.52986, est=3.6291648462409065, details={'was_impossible': False}),
#  Prediction(uid='196', iid='100', r_ui=3.52986, est=3.878207590176354, details={'was_impossible': False}),
#  Prediction(uid='196', iid='432', r_ui=3.52986, est=3.5602008633667013, details={'was_impossible': False}),
#  Prediction(uid='196', iid='322', r_ui=3.52986, est=2.9482286701304665, details={'was_impossible': False}),
#  Prediction(uid='196', iid='181', r_ui=3.52986, est=3.45124732402037, details={'was_impossible': False}),
#  Prediction(uid='196', iid='196', r_ui=3.52986, est=3.880630758080019, details={'was_impossible': False}),
#  Prediction(uid='196', iid='679', r_ui=3.52986, est=3.3527804604637597, details={'was_impossible': False}),
#  Prediction(uid='196', iid='384', r_ui=3.52986, est=3.1575112662422304, details={'was_impossible': False}),
#  Prediction(uid='196', iid='143', r_ui=3.52986, est=3.930780345300894, details={'was_impossible': False}),
#  Prediction(uid='196', iid='423', r_ui=3.52986, est=3.8415241483704055, details={'was_impossible': False}),
#  Prediction(uid='196', iid='515', r_ui=3.52986, est=4.396842772326227, details={'was_impossible': False}),
#  Prediction(uid='196', iid='20', r_ui=3.52986, est=3.435793498151906, details={'was_impossible': False}),
#  Prediction(uid='196', iid='288', r_ui=3.52986, est=3.69938942606349, details={'was_impossible': False}),
#  Prediction(uid='196', iid='219', r_ui=3.52986, est=3.0591393594101457, details={'was_impossible': False}),
#  Prediction(uid='196', iid='526', r_ui=3.52986, est=3.483295709901302, details={'was_impossible': False}),
#  Prediction(uid='196', iid='919', r_ui=3.52986, est=3.5396610573536704, details={'was_impossible': False}),
#  Prediction(uid='196', iid='26', r_ui=3.52986, est=3.326019143123415, details={'was_impossible': False}),
#  Prediction(uid='196', iid='232', r_ui=3.52986, est=3.092169519910232, details={'was_impossible': False}),
#  Prediction(uid='196', iid='427', r_ui=3.52986, est=4.363932140783042, details={'was_impossible': False}),
#  Prediction(uid='196', iid='512', r_ui=3.52986, est=3.9401481015216158, details={'was_impossible': False}),
#  Prediction(uid='196', iid='15', r_ui=3.52986, est=4.058569382431844, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1049', r_ui=3.52986, est=2.6961488476301274, details={'was_impossible': False}),
#  Prediction(uid='196', iid='416', r_ui=3.52986, est=3.6021381790651943, details={'was_impossible': False}),
#  Prediction(uid='196', iid='165', r_ui=3.52986, est=3.95469011266143, details={'was_impossible': False}),
#  Prediction(uid='196', iid='690', r_ui=3.52986, est=3.143346808710584, details={'was_impossible': False}),
#  Prediction(uid='196', iid='248', r_ui=3.52986, est=3.552368667576329, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1444', r_ui=3.52986, est=2.840414206066613, details={'was_impossible': False}),
#  Prediction(uid='196', iid='5', r_ui=3.52986, est=3.4532767948273704, details={'was_impossible': False}),
#  Prediction(uid='196', iid='229', r_ui=3.52986, est=2.9460811537309537, details={'was_impossible': False}),
#  Prediction(uid='196', iid='237', r_ui=3.52986, est=3.3853618603538367, details={'was_impossible': False}),
#  Prediction(uid='196', iid='480', r_ui=3.52986, est=4.148540199850245, details={'was_impossible': False}),
#  Prediction(uid='196', iid='54', r_ui=3.52986, est=3.2048311777452683, details={'was_impossible': False}),
#  Prediction(uid='196', iid='366', r_ui=3.52986, est=3.28658732837481, details={'was_impossible': False}),
#  Prediction(uid='196', iid='518', r_ui=3.52986, est=3.6822125166500235, details={'was_impossible': False}),
#  Prediction(uid='196', iid='403', r_ui=3.52986, est=3.4710746240270693, details={'was_impossible': False}),
#  Prediction(uid='196', iid='625', r_ui=3.52986, est=3.270894553061206, details={'was_impossible': False}),
#  Prediction(uid='196', iid='338', r_ui=3.52986, est=2.690257658534505, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1016', r_ui=3.52986, est=3.52025002129517, details={'was_impossible': False}),
#  Prediction(uid='196', iid='154', r_ui=3.52986, est=3.6359808447257285, details={'was_impossible': False}),
#  Prediction(uid='196', iid='275', r_ui=3.52986, est=3.7240909894329404, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1153', r_ui=3.52986, est=3.7199470301453283, details={'was_impossible': False}),
#  Prediction(uid='196', iid='498', r_ui=3.52986, est=4.193401882429815, details={'was_impossible': False}),
#  Prediction(uid='196', iid='209', r_ui=3.52986, est=3.710062226507168, details={'was_impossible': False}),
#  Prediction(uid='196', iid='23', r_ui=3.52986, est=3.8969965121967007, details={'was_impossible': False}),
#  Prediction(uid='196', iid='294', r_ui=3.52986, est=3.1364223721909994, details={'was_impossible': False}),
#  Prediction(uid='196', iid='208', r_ui=3.52986, est=4.051561361624594, details={'was_impossible': False}),
#  Prediction(uid='196', iid='685', r_ui=3.52986, est=2.955834600698197, details={'was_impossible': False}),
#  Prediction(uid='196', iid='328', r_ui=3.52986, est=3.323828964861174, details={'was_impossible': False}),
#  Prediction(uid='196', iid='496', r_ui=3.52986, est=3.619686290261239, details={'was_impossible': False}),
#  Prediction(uid='196', iid='132', r_ui=3.52986, est=3.9599032851659928, details={'was_impossible': False}),
#  Prediction(uid='196', iid='174', r_ui=3.52986, est=3.858173724696528, details={'was_impossible': False}),
#  Prediction(uid='196', iid='96', r_ui=3.52986, est=4.173587994632138, details={'was_impossible': False}),
#  Prediction(uid='196', iid='151', r_ui=3.52986, est=3.2911058791836973, details={'was_impossible': False}),
#  Prediction(uid='196', iid='307', r_ui=3.52986, est=3.443023721695906, details={'was_impossible': False}),
#  Prediction(uid='196', iid='648', r_ui=3.52986, est=3.897446881285323, details={'was_impossible': False}),
#  Prediction(uid='196', iid='21', r_ui=3.52986, est=2.7356370804711228, details={'was_impossible': False}),
#  Prediction(uid='196', iid='832', r_ui=3.52986, est=2.6960807905875166, details={'was_impossible': False}),
#  Prediction(uid='196', iid='514', r_ui=3.52986, est=3.483956216053448, details={'was_impossible': False}),
#  Prediction(uid='196', iid='789', r_ui=3.52986, est=3.4362719463809945, details={'was_impossible': False}),
#  Prediction(uid='196', iid='485', r_ui=3.52986, est=3.6617435310885345, details={'was_impossible': False}),
#  Prediction(uid='196', iid='317', r_ui=3.52986, est=3.7796837720011256, details={'was_impossible': False}),
#  Prediction(uid='196', iid='195', r_ui=3.52986, est=3.621117049153212, details={'was_impossible': False}),
#  Prediction(uid='196', iid='200', r_ui=3.52986, est=3.8706985052844134, details={'was_impossible': False}),
#  Prediction(uid='196', iid='385', r_ui=3.52986, est=3.578724239685325, details={'was_impossible': False}),
#  Prediction(uid='196', iid='750', r_ui=3.52986, est=3.754085612621144, details={'was_impossible': False}),
#  Prediction(uid='196', iid='264', r_ui=3.52986, est=2.7837304461841526, details={'was_impossible': False}),
#  Prediction(uid='196', iid='245', r_ui=3.52986, est=3.047461130531222, details={'was_impossible': False}),
#  Prediction(uid='196', iid='135', r_ui=3.52986, est=3.737682387331194, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1147', r_ui=3.52986, est=3.6486596797932207, details={'was_impossible': False}),
#  Prediction(uid='196', iid='471', r_ui=3.52986, est=3.7167760218702246, details={'was_impossible': False}),
#  Prediction(uid='196', iid='658', r_ui=3.52986, est=3.619425952131688, details={'was_impossible': False}),
#  Prediction(uid='196', iid='140', r_ui=3.52986, est=3.1439423102329327, details={'was_impossible': False}),
#  Prediction(uid='196', iid='379', r_ui=3.52986, est=3.2490484617103634, details={'was_impossible': False}),
#  Prediction(uid='196', iid='815', r_ui=3.52986, est=3.294186229018777, details={'was_impossible': False}),
#  Prediction(uid='196', iid='479', r_ui=3.52986, est=4.28509137042794, details={'was_impossible': False}),
#  Prediction(uid='196', iid='368', r_ui=3.52986, est=1.9464315851031382, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1211', r_ui=3.52986, est=3.6162160754141612, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1134', r_ui=3.52986, est=3.249180038105548, details={'was_impossible': False}),
#  Prediction(uid='196', iid='836', r_ui=3.52986, est=3.6823771542558297, details={'was_impossible': False}),
#  Prediction(uid='196', iid='272', r_ui=3.52986, est=4.426936726882625, details={'was_impossible': False}),
#  Prediction(uid='196', iid='756', r_ui=3.52986, est=3.0569854206437, details={'was_impossible': False}),
#  Prediction(uid='196', iid='787', r_ui=3.52986, est=3.1788176700817194, details={'was_impossible': False}),
#  Prediction(uid='196', iid='14', r_ui=3.52986, est=4.11784025283752, details={'was_impossible': False}),
#  Prediction(uid='196', iid='955', r_ui=3.52986, est=3.2632510620345974, details={'was_impossible': False}),
#  Prediction(uid='196', iid='419', r_ui=3.52986, est=3.6537722259762595, details={'was_impossible': False}),
#  Prediction(uid='196', iid='405', r_ui=3.52986, est=3.313039752932435, details={'was_impossible': False}),
#  Prediction(uid='196', iid='504', r_ui=3.52986, est=3.7448926947702907, details={'was_impossible': False}),
#  Prediction(uid='196', iid='466', r_ui=3.52986, est=3.7611988536662597, details={'was_impossible': False}),
#  Prediction(uid='196', iid='268', r_ui=3.52986, est=3.7973353203196183, details={'was_impossible': False}),
#  Prediction(uid='196', iid='117', r_ui=3.52986, est=3.657244644623452, details={'was_impossible': False}),
#  Prediction(uid='196', iid='273', r_ui=3.52986, est=3.4319840141203732, details={'was_impossible': False}),
#  Prediction(uid='196', iid='559', r_ui=3.52986, est=3.300560312256398, details={'was_impossible': False}),
#  Prediction(uid='196', iid='794', r_ui=3.52986, est=3.4247899682516736, details={'was_impossible': False}),
#  Prediction(uid='196', iid='323', r_ui=3.52986, est=2.8045035583986975, details={'was_impossible': False}),
#  Prediction(uid='196', iid='177', r_ui=3.52986, est=3.5587663603635074, details={'was_impossible': False}),
#  Prediction(uid='196', iid='231', r_ui=3.52986, est=2.841289421578472, details={'was_impossible': False}),
#  Prediction(uid='196', iid='2', r_ui=3.52986, est=3.225669657467808, details={'was_impossible': False}),
#  Prediction(uid='196', iid='137', r_ui=3.52986, est=3.8629050659433037, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1336', r_ui=3.52986, est=2.783523279749941, details={'was_impossible': False}),
#  Prediction(uid='196', iid='164', r_ui=3.52986, est=3.574064092985437, details={'was_impossible': False}),
#  Prediction(uid='196', iid='281', r_ui=3.52986, est=3.158674708703465, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1240', r_ui=3.52986, est=3.791278353058416, details={'was_impossible': False}),
#  Prediction(uid='196', iid='298', r_ui=3.52986, est=3.9403028975553553, details={'was_impossible': False}),
#  Prediction(uid='196', iid='443', r_ui=3.52986, est=3.6244139330625487, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1035', r_ui=3.52986, est=3.0399339772966942, details={'was_impossible': False}),
#  Prediction(uid='196', iid='79', r_ui=3.52986, est=3.7791068362886575, details={'was_impossible': False}),
#  Prediction(uid='196', iid='258', r_ui=3.52986, est=3.666895300867514, details={'was_impossible': False}),
#  Prediction(uid='196', iid='455', r_ui=3.52986, est=3.116783665055376, details={'was_impossible': False}),
#  Prediction(uid='196', iid='755', r_ui=3.52986, est=3.2310705126894956, details={'was_impossible': False}),
#  Prediction(uid='196', iid='673', r_ui=3.52986, est=3.649673593975649, details={'was_impossible': False}),
#  Prediction(uid='196', iid='172', r_ui=3.52986, est=3.6580006470105517, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1217', r_ui=3.52986, est=3.11606892533038, details={'was_impossible': False}),
#  Prediction(uid='196', iid='719', r_ui=3.52986, est=2.590490884516976, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1267', r_ui=3.52986, est=3.1525643288331358, details={'was_impossible': False}),
#  Prediction(uid='196', iid='930', r_ui=3.52986, est=2.713930955649427, details={'was_impossible': False}),
#  Prediction(uid='196', iid='216', r_ui=3.52986, est=3.7480002024558816, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1079', r_ui=3.52986, est=2.3176724412552447, details={'was_impossible': False}),
#  Prediction(uid='196', iid='452', r_ui=3.52986, est=2.8189994523994026, details={'was_impossible': False}),
#  Prediction(uid='196', iid='61', r_ui=3.52986, est=4.039878046113872, details={'was_impossible': False}),
#  Prediction(uid='196', iid='48', r_ui=3.52986, est=3.8788325529609513, details={'was_impossible': False}),
#  Prediction(uid='196', iid='360', r_ui=3.52986, est=3.2359955952972004, details={'was_impossible': False}),
#  Prediction(uid='196', iid='77', r_ui=3.52986, est=3.2428308376996133, details={'was_impossible': False}),
#  Prediction(uid='196', iid='476', r_ui=3.52986, est=3.5785400062089763, details={'was_impossible': False}),
#  Prediction(uid='196', iid='483', r_ui=3.52986, est=4.22809056003696, details={'was_impossible': False}),
#  Prediction(uid='196', iid='748', r_ui=3.52986, est=2.711924256133244, details={'was_impossible': False}),
#  Prediction(uid='196', iid='220', r_ui=3.52986, est=3.3082218179621834, details={'was_impossible': False}),
#  Prediction(uid='196', iid='255', r_ui=3.52986, est=3.4837522701332615, details={'was_impossible': False}),
#  Prediction(uid='196', iid='280', r_ui=3.52986, est=3.1049109179571155, details={'was_impossible': False}),
#  Prediction(uid='196', iid='408', r_ui=3.52986, est=4.581446694982468, details={'was_impossible': False}),
#  Prediction(uid='196', iid='235', r_ui=3.52986, est=3.25702063071283, details={'was_impossible': False}),
#  Prediction(uid='196', iid='228', r_ui=3.52986, est=3.593762719202629, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1098', r_ui=3.52986, est=3.675595342624598, details={'was_impossible': False}),
#  Prediction(uid='196', iid='347', r_ui=3.52986, est=3.4695070408675974, details={'was_impossible': False}),
#  Prediction(uid='196', iid='178', r_ui=3.52986, est=4.328249632603196, details={'was_impossible': False}),
#  Prediction(uid='196', iid='478', r_ui=3.52986, est=3.9606187980646443, details={'was_impossible': False}),
#  Prediction(uid='196', iid='688', r_ui=3.52986, est=2.091336439105237, details={'was_impossible': False}),
#  Prediction(uid='196', iid='10', r_ui=3.52986, est=3.962947758885358, details={'was_impossible': False}),
#  Prediction(uid='196', iid='127', r_ui=3.52986, est=3.6530758201468645, details={'was_impossible': False}),
#  Prediction(uid='196', iid='106', r_ui=3.52986, est=2.9783807230374495, details={'was_impossible': False}),
#  Prediction(uid='196', iid='69', r_ui=3.52986, est=3.456722109882891, details={'was_impossible': False}),
#  Prediction(uid='196', iid='944', r_ui=3.52986, est=2.9209771694106976, details={'was_impossible': False}),
#  Prediction(uid='196', iid='790', r_ui=3.52986, est=2.934823570339163, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1091', r_ui=3.52986, est=2.5881928930672857, details={'was_impossible': False}),
#  Prediction(uid='196', iid='214', r_ui=3.52986, est=3.4129811820357143, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1028', r_ui=3.52986, est=3.3567427499563056, details={'was_impossible': False}),
#  Prediction(uid='196', iid='554', r_ui=3.52986, est=2.827588468157733, details={'was_impossible': False}),
#  Prediction(uid='196', iid='109', r_ui=3.52986, est=3.180334992638703, details={'was_impossible': False}),
#  Prediction(uid='196', iid='171', r_ui=3.52986, est=3.908988633580792, details={'was_impossible': False}),
#  Prediction(uid='196', iid='318', r_ui=3.52986, est=4.4018422595822155, details={'was_impossible': False}),
#  Prediction(uid='196', iid='568', r_ui=3.52986, est=3.6730692740998774, details={'was_impossible': False}),
#  Prediction(uid='196', iid='842', r_ui=3.52986, est=3.1142716019788628, details={'was_impossible': False}),
#  Prediction(uid='196', iid='65', r_ui=3.52986, est=3.430415285151569, details={'was_impossible': False}),
#  Prediction(uid='196', iid='591', r_ui=3.52986, est=3.6245753337682585, details={'was_impossible': False}),
#  Prediction(uid='196', iid='401', r_ui=3.52986, est=2.954958308849248, details={'was_impossible': False}),
#  Prediction(uid='196', iid='339', r_ui=3.52986, est=3.1418977154972976, details={'was_impossible': False}),
#  Prediction(uid='196', iid='746', r_ui=3.52986, est=3.687699575062984, details={'was_impossible': False}),
#  Prediction(uid='196', iid='68', r_ui=3.52986, est=3.421161077857615, details={'was_impossible': False}),
#  Prediction(uid='196', iid='7', r_ui=3.52986, est=4.05403218098283, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1018', r_ui=3.52986, est=3.4288865800266257, details={'was_impossible': False}),
#  Prediction(uid='196', iid='218', r_ui=3.52986, est=3.626428883707553, details={'was_impossible': False}),
#  Prediction(uid='196', iid='623', r_ui=3.52986, est=3.0641077564306705, details={'was_impossible': False}),
#  Prediction(uid='196', iid='334', r_ui=3.52986, est=2.9877477823209295, details={'was_impossible': False}),
#  Prediction(uid='196', iid='344', r_ui=3.52986, est=3.9801109256843903, details={'was_impossible': False}),
#  Prediction(uid='196', iid='145', r_ui=3.52986, est=2.6027732852116965, details={'was_impossible': False}),
#  Prediction(uid='196', iid='56', r_ui=3.52986, est=4.061631553039136, details={'was_impossible': False}),
#  Prediction(uid='196', iid='89', r_ui=3.52986, est=4.0645728681530535, details={'was_impossible': False}),
#  Prediction(uid='196', iid='141', r_ui=3.52986, est=3.6233467950652725, details={'was_impossible': False}),
#  Prediction(uid='196', iid='576', r_ui=3.52986, est=3.3078410934800284, details={'was_impossible': False}),
#  Prediction(uid='196', iid='133', r_ui=3.52986, est=3.9331818688812707, details={'was_impossible': False}),
#  Prediction(uid='196', iid='813', r_ui=3.52986, est=4.028217548768975, details={'was_impossible': False}),
#  Prediction(uid='196', iid='872', r_ui=3.52986, est=3.141362265396112, details={'was_impossible': False}),
#  Prediction(uid='196', iid='146', r_ui=3.52986, est=2.9514905273118237, details={'was_impossible': False}),
#  Prediction(uid='196', iid='507', r_ui=3.52986, est=3.9547423397078556, details={'was_impossible': False}),
#  Prediction(uid='196', iid='367', r_ui=3.52986, est=3.6850289660501354, details={'was_impossible': False}),
#  Prediction(uid='196', iid='468', r_ui=3.52986, est=3.169130143117881, details={'was_impossible': False}),
#  Prediction(uid='196', iid='595', r_ui=3.52986, est=3.1990818413600546, details={'was_impossible': False}),
#  Prediction(uid='196', iid='11', r_ui=3.52986, est=4.017405303698764, details={'was_impossible': False}),
#  Prediction(uid='196', iid='520', r_ui=3.52986, est=4.068722209098212, details={'was_impossible': False}),
#  Prediction(uid='196', iid='82', r_ui=3.52986, est=3.6325142443001126, details={'was_impossible': False}),
#  Prediction(uid='196', iid='501', r_ui=3.52986, est=3.608792171683387, details={'was_impossible': False}),
#  Prediction(uid='196', iid='3', r_ui=3.52986, est=3.0080011997831138, details={'was_impossible': False}),
#  Prediction(uid='196', iid='695', r_ui=3.52986, est=3.4048874185963522, details={'was_impossible': False}),
#  Prediction(uid='196', iid='198', r_ui=3.52986, est=3.8801014333921455, details={'was_impossible': False}),
#  Prediction(uid='196', iid='189', r_ui=3.52986, est=4.242300733818561, details={'was_impossible': False}),
#  Prediction(uid='196', iid='767', r_ui=3.52986, est=2.872119494807291, details={'was_impossible': False}),
#  Prediction(uid='196', iid='705', r_ui=3.52986, est=3.8290459597166473, details={'was_impossible': False}),
#  Prediction(uid='196', iid='64', r_ui=3.52986, est=4.291820997899128, details={'was_impossible': False}),
#  Prediction(uid='196', iid='357', r_ui=3.52986, est=4.2118697370451885, details={'was_impossible': False}),
#  Prediction(uid='196', iid='484', r_ui=3.52986, est=4.081339934105963, details={'was_impossible': False}),
#  Prediction(uid='196', iid='508', r_ui=3.52986, est=3.619478571396464, details={'was_impossible': False}),
#  Prediction(uid='196', iid='303', r_ui=3.52986, est=3.90943626894768, details={'was_impossible': False}),
#  Prediction(uid='196', iid='215', r_ui=3.52986, est=3.300375612463506, details={'was_impossible': False}),
#  Prediction(uid='196', iid='749', r_ui=3.52986, est=3.199418619508155, details={'was_impossible': False}),
#  Prediction(uid='196', iid='829', r_ui=3.52986, est=2.665055863262923, details={'was_impossible': False}),
#  Prediction(uid='196', iid='204', r_ui=3.52986, est=3.457684889136516, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1295', r_ui=3.52986, est=3.2109117882767215, details={'was_impossible': False}),
#  Prediction(uid='196', iid='33', r_ui=3.52986, est=3.4583719859535504, details={'was_impossible': False}),
#  Prediction(uid='196', iid='160', r_ui=3.52986, est=3.447605786182653, details={'was_impossible': False}),
#  Prediction(uid='196', iid='321', r_ui=3.52986, est=3.119342425195023, details={'was_impossible': False}),
#  Prediction(uid='196', iid='343', r_ui=3.52986, est=3.2157188716310685, details={'was_impossible': False}),
#  Prediction(uid='196', iid='227', r_ui=3.52986, est=3.1954149480113276, details={'was_impossible': False}),
#  Prediction(uid='196', iid='191', r_ui=3.52986, est=4.113709703089709, details={'was_impossible': False}),
#  Prediction(uid='196', iid='903', r_ui=3.52986, est=3.3150880329501433, details={'was_impossible': False}),
#  Prediction(uid='196', iid='183', r_ui=3.52986, est=3.946006269620076, details={'was_impossible': False}),
#  Prediction(uid='196', iid='724', r_ui=3.52986, est=3.57693505664079, details={'was_impossible': False}),
#  Prediction(uid='196', iid='430', r_ui=3.52986, est=3.7493096824497987, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1197', r_ui=3.52986, est=3.4775988152689816, details={'was_impossible': False}),
#  Prediction(uid='196', iid='134', r_ui=3.52986, est=4.335195200701295, details={'was_impossible': False}),
#  Prediction(uid='196', iid='751', r_ui=3.52986, est=3.210553388921861, details={'was_impossible': False}),
#  Prediction(uid='196', iid='212', r_ui=3.52986, est=3.780033047818419, details={'was_impossible': False}),
#  Prediction(uid='196', iid='256', r_ui=3.52986, est=3.783784608820765, details={'was_impossible': False}),
#  Prediction(uid='196', iid='662', r_ui=3.52986, est=3.144697463310187, details={'was_impossible': False}),
#  Prediction(uid='196', iid='984', r_ui=3.52986, est=2.8834004170274983, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1067', r_ui=3.52986, est=3.6880955778046176, details={'was_impossible': False}),
#  Prediction(uid='196', iid='410', r_ui=3.52986, est=3.2676308806244587, details={'was_impossible': False}),
#  Prediction(uid='196', iid='879', r_ui=3.52986, est=3.379306068719548, details={'was_impossible': False}),
#  Prediction(uid='196', iid='271', r_ui=3.52986, est=3.094321740368927, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1086', r_ui=3.52986, est=3.4336560037998187, details={'was_impossible': False}),
#  Prediction(uid='196', iid='649', r_ui=3.52986, est=3.4771939280306565, details={'was_impossible': False}),
#  Prediction(uid='196', iid='951', r_ui=3.52986, est=2.834814464559237, details={'was_impossible': False}),
#  Prediction(uid='196', iid='197', r_ui=3.52986, est=3.9381146721872375, details={'was_impossible': False}),
#  Prediction(uid='196', iid='678', r_ui=3.52986, est=3.124455294372585, details={'was_impossible': False}),
#  Prediction(uid='196', iid='199', r_ui=3.52986, est=3.937777093661435, details={'was_impossible': False}),
#  Prediction(uid='196', iid='709', r_ui=3.52986, est=4.15778378726149, details={'was_impossible': False}),
#  Prediction(uid='196', iid='169', r_ui=3.52986, est=4.306750779042094, details={'was_impossible': False}),
#  Prediction(uid='196', iid='597', r_ui=3.52986, est=2.942855831633209, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1393', r_ui=3.52986, est=2.938120544003437, details={'was_impossible': False}),
#  Prediction(uid='196', iid='333', r_ui=3.52986, est=3.7814592350054776, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1115', r_ui=3.52986, est=3.3525003327299783, details={'was_impossible': False}),
#  Prediction(uid='196', iid='577', r_ui=3.52986, est=2.6114982134438134, details={'was_impossible': False}),
#  Prediction(uid='196', iid='378', r_ui=3.52986, est=3.749517894093515, details={'was_impossible': False}),
#  Prediction(uid='196', iid='425', r_ui=3.52986, est=3.8330694889465153, details={'was_impossible': False}),
#  Prediction(uid='196', iid='959', r_ui=3.52986, est=3.3064240736807893, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1224', r_ui=3.52986, est=3.169681277241385, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1017', r_ui=3.52986, est=3.192017825894556, details={'was_impossible': False}),
#  Prediction(uid='196', iid='175', r_ui=3.52986, est=3.959863068080389, details={'was_impossible': False}),
#  Prediction(uid='196', iid='558', r_ui=3.52986, est=3.897855050513362, details={'was_impossible': False}),
#  Prediction(uid='196', iid='206', r_ui=3.52986, est=3.467908560521096, details={'was_impossible': False}),
#  Prediction(uid='196', iid='402', r_ui=3.52986, est=3.5424492152306684, details={'was_impossible': False}),
#  Prediction(uid='196', iid='640', r_ui=3.52986, est=3.2424535164748813, details={'was_impossible': False}),
#  Prediction(uid='196', iid='522', r_ui=3.52986, est=3.72901636927709, details={'was_impossible': False}),
#  Prediction(uid='196', iid='62', r_ui=3.52986, est=2.9377015774007305, details={'was_impossible': False}),
#  Prediction(uid='196', iid='12', r_ui=3.52986, est=4.444347542817535, details={'was_impossible': False}),
#  Prediction(uid='196', iid='291', r_ui=3.52986, est=3.407657415236528, details={'was_impossible': False}),
#  Prediction(uid='196', iid='462', r_ui=3.52986, est=3.832436465181592, details={'was_impossible': False}),
#  Prediction(uid='196', iid='612', r_ui=3.52986, est=3.676881919322376, details={'was_impossible': False}),
#  Prediction(uid='196', iid='758', r_ui=3.52986, est=2.2333591000733577, details={'was_impossible': False}),
#  Prediction(uid='196', iid='163', r_ui=3.52986, est=3.667465922682545, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1451', r_ui=3.52986, est=3.6681896045180156, details={'was_impossible': False}),
#  Prediction(uid='196', iid='250', r_ui=3.52986, est=3.336489387886908, details={'was_impossible': False}),
#  Prediction(uid='196', iid='823', r_ui=3.52986, est=2.8488671460371995, details={'was_impossible': False}),
#  Prediction(uid='196', iid='186', r_ui=3.52986, est=3.5032990517107887, details={'was_impossible': False}),
#  Prediction(uid='196', iid='731', r_ui=3.52986, est=3.3491587345184417, details={'was_impossible': False}),
#  Prediction(uid='196', iid='71', r_ui=3.52986, est=3.7340115686433912, details={'was_impossible': False}),
#  Prediction(uid='196', iid='781', r_ui=3.52986, est=3.2945773459672534, details={'was_impossible': False}),
#  Prediction(uid='196', iid='176', r_ui=3.52986, est=3.8282701480329497, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1181', r_ui=3.52986, est=2.653635086699013, details={'was_impossible': False}),
#  Prediction(uid='196', iid='78', r_ui=3.52986, est=2.9110651446174924, details={'was_impossible': False}),
#  Prediction(uid='196', iid='436', r_ui=3.52986, est=3.6811178853562834, details={'was_impossible': False}),
#  Prediction(uid='196', iid='631', r_ui=3.52986, est=3.9558695417221434, details={'was_impossible': False}),
#  Prediction(uid='196', iid='716', r_ui=3.52986, est=3.2372510541307142, details={'was_impossible': False}),
#  Prediction(uid='196', iid='188', r_ui=3.52986, est=3.5841713050439337, details={'was_impossible': False}),
#  Prediction(uid='196', iid='699', r_ui=3.52986, est=3.749944749796736, details={'was_impossible': False}),
#  Prediction(uid='196', iid='604', r_ui=3.52986, est=4.2252555806424414, details={'was_impossible': False}),
#  Prediction(uid='196', iid='97', r_ui=3.52986, est=3.779926583466911, details={'was_impossible': False}),
#  Prediction(uid='196', iid='460', r_ui=3.52986, est=2.9986607882157204, details={'was_impossible': False}),
#  Prediction(uid='196', iid='715', r_ui=3.52986, est=3.432193487372487, details={'was_impossible': False}),
#  Prediction(uid='196', iid='17', r_ui=3.52986, est=3.250188621040664, details={'was_impossible': False}),
#  Prediction(uid='196', iid='315', r_ui=3.52986, est=4.100963183941213, details={'was_impossible': False}),
#  Prediction(uid='196', iid='505', r_ui=3.52986, est=4.131418459158682, details={'was_impossible': False}),
#  Prediction(uid='196', iid='279', r_ui=3.52986, est=3.047092816405268, details={'was_impossible': False}),
#  Prediction(uid='196', iid='80', r_ui=3.52986, est=2.846441793746325, details={'was_impossible': False}),
#  Prediction(uid='196', iid='60', r_ui=3.52986, est=3.9276559724908404, details={'was_impossible': False}),
#  Prediction(uid='196', iid='325', r_ui=3.52986, est=3.068151645562856, details={'was_impossible': False}),
#  Prediction(uid='196', iid='407', r_ui=3.52986, est=2.4647374707498586, details={'was_impossible': False}),
#  Prediction(uid='196', iid='531', r_ui=3.52986, est=3.870214427952242, details={'was_impossible': False}),
#  Prediction(uid='196', iid='587', r_ui=3.52986, est=3.481180302391179, details={'was_impossible': False}),
#  Prediction(uid='196', iid='892', r_ui=3.52986, est=2.7600923480934987, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1047', r_ui=3.52986, est=2.7235762691688734, details={'was_impossible': False}),
#  Prediction(uid='196', iid='47', r_ui=3.52986, est=3.2699922880886625, details={'was_impossible': False}),
#  Prediction(uid='196', iid='217', r_ui=3.52986, est=3.6493719091304304, details={'was_impossible': False}),
#  Prediction(uid='196', iid='259', r_ui=3.52986, est=3.2970666489377143, details={'was_impossible': False}),
#  Prediction(uid='196', iid='596', r_ui=3.52986, est=3.337959520707265, details={'was_impossible': False}),
#  Prediction(uid='196', iid='960', r_ui=3.52986, est=3.333294228343387, details={'was_impossible': False}),
#  Prediction(uid='196', iid='211', r_ui=3.52986, est=3.608100745284795, details={'was_impossible': False}),
#  Prediction(uid='196', iid='938', r_ui=3.52986, est=2.7259963772489524, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1060', r_ui=3.52986, est=3.080132872330989, details={'was_impossible': False}),
#  Prediction(uid='196', iid='404', r_ui=3.52986, est=3.6564123138630302, details={'was_impossible': False}),
#  Prediction(uid='196', iid='305', r_ui=3.52986, est=3.4951650062140702, details={'was_impossible': False}),
#  Prediction(uid='196', iid='210', r_ui=3.52986, est=3.9384231969866685, details={'was_impossible': False}),
#  Prediction(uid='196', iid='278', r_ui=3.52986, est=3.250401462999782, details={'was_impossible': False}),
#  Prediction(uid='196', iid='770', r_ui=3.52986, est=3.2390233201134633, details={'was_impossible': False}),
#  Prediction(uid='196', iid='252', r_ui=3.52986, est=3.254462379230719, details={'was_impossible': False}),
#  Prediction(uid='196', iid='156', r_ui=3.52986, est=3.963070109767091, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1110', r_ui=3.52986, est=2.9577990388845072, details={'was_impossible': False}),
#  Prediction(uid='196', iid='350', r_ui=3.52986, est=3.441546027596578, details={'was_impossible': False}),
#  Prediction(uid='196', iid='431', r_ui=3.52986, est=3.281380336536594, details={'was_impossible': False}),
#  Prediction(uid='196', iid='475', r_ui=3.52986, est=3.81704730448135, details={'was_impossible': False}),
#  Prediction(uid='196', iid='182', r_ui=3.52986, est=3.4606057524220155, details={'was_impossible': False}),
#  Prediction(uid='196', iid='50', r_ui=3.52986, est=3.8316811970018825, details={'was_impossible': False}),
#  Prediction(uid='196', iid='365', r_ui=3.52986, est=3.214404422661237, details={'was_impossible': False}),
#  Prediction(uid='196', iid='187', r_ui=3.52986, est=3.751120969062865, details={'was_impossible': False}),
#  Prediction(uid='196', iid='289', r_ui=3.52986, est=3.083170276592424, details={'was_impossible': False}),
#  Prediction(uid='196', iid='185', r_ui=3.52986, est=3.987373425463864, details={'was_impossible': False}),
#  Prediction(uid='196', iid='712', r_ui=3.52986, est=3.266402958239298, details={'was_impossible': False}),
#  Prediction(uid='196', iid='742', r_ui=3.52986, est=3.5640253351657902, details={'was_impossible': False}),
#  Prediction(uid='196', iid='732', r_ui=3.52986, est=3.535504487947759, details={'was_impossible': False}),
#  Prediction(uid='196', iid='168', r_ui=3.52986, est=3.9153091987889224, details={'was_impossible': False}),
#  Prediction(uid='196', iid='550', r_ui=3.52986, est=3.2461776435056096, details={'was_impossible': False}),
#  Prediction(uid='196', iid='849', r_ui=3.52986, est=3.1568772217808414, details={'was_impossible': False}),
#  Prediction(uid='196', iid='406', r_ui=3.52986, est=2.5455630747393374, details={'was_impossible': False}),
#  Prediction(uid='196', iid='150', r_ui=3.52986, est=3.6946204545253947, details={'was_impossible': False}),
#  Prediction(uid='196', iid='869', r_ui=3.52986, est=2.837894737558588, details={'was_impossible': False}),
#  Prediction(uid='196', iid='184', r_ui=3.52986, est=3.5769145691261897, details={'was_impossible': False}),
#  Prediction(uid='196', iid='371', r_ui=3.52986, est=3.0134123350242015, details={'was_impossible': False}),
#  Prediction(uid='196', iid='720', r_ui=3.52986, est=2.907378781916934, details={'was_impossible': False}),
#  Prediction(uid='196', iid='873', r_ui=3.52986, est=3.045928573662583, details={'was_impossible': False}),
#  Prediction(uid='196', iid='922', r_ui=3.52986, est=3.812186719330398, details={'was_impossible': False}),
#  Prediction(uid='196', iid='57', r_ui=3.52986, est=3.984947655578778, details={'was_impossible': False}),
#  Prediction(uid='196', iid='370', r_ui=3.52986, est=2.807221715516773, details={'was_impossible': False}),
#  Prediction(uid='196', iid='249', r_ui=3.52986, est=3.5500468291758493, details={'was_impossible': False}),
#  Prediction(uid='196', iid='721', r_ui=3.52986, est=3.5199651357766717, details={'was_impossible': False}),
#  Prediction(uid='196', iid='611', r_ui=3.52986, est=4.02760133666968, details={'was_impossible': False}),
#  Prediction(uid='196', iid='142', r_ui=3.52986, est=3.0314611614966456, details={'was_impossible': False}),
#  Prediction(uid='196', iid='943', r_ui=3.52986, est=3.582355835457397, details={'was_impossible': False}),
#  Prediction(uid='196', iid='126', r_ui=3.52986, est=3.795164026940107, details={'was_impossible': False}),
#  Prediction(uid='196', iid='824', r_ui=3.52986, est=2.5597598464881353, details={'was_impossible': False}),
#  Prediction(uid='196', iid='58', r_ui=3.52986, est=3.7714852354782056, details={'was_impossible': False}),
#  Prediction(uid='196', iid='680', r_ui=3.52986, est=2.5914114792058323, details={'was_impossible': False}),
#  Prediction(uid='196', iid='741', r_ui=3.52986, est=3.3696301865183793, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1061', r_ui=3.52986, est=3.185714018415412, details={'was_impossible': False}),
#  Prediction(uid='196', iid='448', r_ui=3.52986, est=3.5675915023140363, details={'was_impossible': False}),
#  Prediction(uid='196', iid='900', r_ui=3.52986, est=3.6483628851588055, details={'was_impossible': False}),
#  Prediction(uid='196', iid='941', r_ui=3.52986, est=2.9558410437787943, details={'was_impossible': False}),
#  Prediction(uid='196', iid='905', r_ui=3.52986, est=3.227836426210209, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1497', r_ui=3.52986, est=3.1763753281530147, details={'was_impossible': False}),
#  Prediction(uid='196', iid='55', r_ui=3.52986, est=3.34294101956926, details={'was_impossible': False}),
#  Prediction(uid='196', iid='744', r_ui=3.52986, est=3.6093630489250326, details={'was_impossible': False}),
#  Prediction(uid='196', iid='642', r_ui=3.52986, est=3.609367033839562, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1015', r_ui=3.52986, est=3.1528055923440856, details={'was_impossible': False}),
#  Prediction(uid='196', iid='121', r_ui=3.52986, est=3.719209844183568, details={'was_impossible': False}),
#  Prediction(uid='196', iid='301', r_ui=3.52986, est=3.0822982295694468, details={'was_impossible': False}),
#  Prediction(uid='196', iid='81', r_ui=3.52986, est=3.245623051301566, details={'was_impossible': False}),
#  Prediction(uid='196', iid='284', r_ui=3.52986, est=3.20789631051144, details={'was_impossible': False}),
#  Prediction(uid='196', iid='740', r_ui=3.52986, est=3.5735699068351434, details={'was_impossible': False}),
#  Prediction(uid='196', iid='22', r_ui=3.52986, est=3.8324005181887326, details={'was_impossible': False}),
#  Prediction(uid='196', iid='864', r_ui=3.52986, est=3.2358227241240196, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1099', r_ui=3.52986, est=3.710145963535219, details={'was_impossible': False}),
#  Prediction(uid='196', iid='961', r_ui=3.52986, est=3.5260882716512296, details={'was_impossible': False}),
#  Prediction(uid='196', iid='812', r_ui=3.52986, est=3.0787626610057734, details={'was_impossible': False}),
#  Prediction(uid='196', iid='240', r_ui=3.52986, est=2.7843235342604635, details={'was_impossible': False}),
#  Prediction(uid='196', iid='376', r_ui=3.52986, est=3.1949193834149643, details={'was_impossible': False}),
#  Prediction(uid='196', iid='931', r_ui=3.52986, est=2.1978267447634634, details={'was_impossible': False}),
#  Prediction(uid='196', iid='717', r_ui=3.52986, est=2.831166670530373, details={'was_impossible': False}),
#  Prediction(uid='196', iid='399', r_ui=3.52986, est=3.5722190101215023, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1039', r_ui=3.52986, est=3.863681437750033, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1114', r_ui=3.52986, est=3.6004446701511124, details={'was_impossible': False}),
#  Prediction(uid='196', iid='292', r_ui=3.52986, est=3.502201561032674, details={'was_impossible': False}),
#  Prediction(uid='196', iid='561', r_ui=3.52986, est=3.2393528873067114, details={'was_impossible': False}),
#  Prediction(uid='196', iid='901', r_ui=3.52986, est=2.706726639736329, details={'was_impossible': False}),
#  Prediction(uid='196', iid='417', r_ui=3.52986, est=3.2718995615472215, details={'was_impossible': False}),
#  Prediction(uid='196', iid='809', r_ui=3.52986, est=2.9757092220945105, details={'was_impossible': False}),
#  Prediction(uid='196', iid='540', r_ui=3.52986, est=2.640837823866031, details={'was_impossible': False}),
#  Prediction(uid='196', iid='293', r_ui=3.52986, est=3.6788140452629197, details={'was_impossible': False}),
#  Prediction(uid='196', iid='497', r_ui=3.52986, est=3.722315261227004, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1462', r_ui=3.52986, est=3.6554439172583377, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1246', r_ui=3.52986, est=2.6869114199994764, details={'was_impossible': False}),
#  Prediction(uid='196', iid='588', r_ui=3.52986, est=3.698021381149004, details={'was_impossible': False}),
#  Prediction(uid='196', iid='409', r_ui=3.52986, est=3.0099848074106994, details={'was_impossible': False}),
#  Prediction(uid='196', iid='739', r_ui=3.52986, est=3.204074819117373, details={'was_impossible': False}),
#  Prediction(uid='196', iid='661', r_ui=3.52986, est=4.03771080565862, details={'was_impossible': False}),
#  Prediction(uid='196', iid='665', r_ui=3.52986, est=3.1313837298883014, details={'was_impossible': False}),
#  Prediction(uid='196', iid='439', r_ui=3.52986, est=2.819590698418544, details={'was_impossible': False}),
#  Prediction(uid='196', iid='632', r_ui=3.52986, est=3.7188524141341874, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1198', r_ui=3.52986, est=3.4850934894098784, details={'was_impossible': False}),
#  Prediction(uid='196', iid='609', r_ui=3.52986, est=3.6129506146826005, details={'was_impossible': False}),
#  Prediction(uid='196', iid='225', r_ui=3.52986, est=3.0925029794502863, details={'was_impossible': False}),
#  Prediction(uid='196', iid='128', r_ui=3.52986, est=3.487616135907741, details={'was_impossible': False}),
#  Prediction(uid='196', iid='866', r_ui=3.52986, est=3.330163175520986, details={'was_impossible': False}),
#  Prediction(uid='196', iid='295', r_ui=3.52986, est=3.350903009021945, details={'was_impossible': False}),
#  Prediction(uid='196', iid='49', r_ui=3.52986, est=3.3220900843192687, details={'was_impossible': False}),
#  Prediction(uid='196', iid='626', r_ui=3.52986, est=3.2968095012781733, details={'was_impossible': False}),
#  Prediction(uid='196', iid='707', r_ui=3.52986, est=4.176288662859425, details={'was_impossible': False}),
#  Prediction(uid='196', iid='586', r_ui=3.52986, est=2.7837797297032947, details={'was_impossible': False}),
#  Prediction(uid='196', iid='593', r_ui=3.52986, est=3.3561974355252255, details={'was_impossible': False}),
#  Prediction(uid='196', iid='147', r_ui=3.52986, est=3.5350942463648707, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1220', r_ui=3.52986, est=3.4058566570577278, details={'was_impossible': False}),
#  Prediction(uid='196', iid='492', r_ui=3.52986, est=3.8343798460094445, details={'was_impossible': False}),
#  Prediction(uid='196', iid='620', r_ui=3.52986, est=2.811018916984918, details={'was_impossible': False}),
#  Prediction(uid='196', iid='161', r_ui=3.52986, est=3.5012440329646317, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1070', r_ui=3.52986, est=3.8814832189874577, details={'was_impossible': False}),
#  Prediction(uid='196', iid='449', r_ui=3.52986, est=3.060562340547648, details={'was_impossible': False}),
#  Prediction(uid='196', iid='948', r_ui=3.52986, est=2.2722972137353827, details={'was_impossible': False}),
#  Prediction(uid='196', iid='509', r_ui=3.52986, est=3.8798093981276485, details={'was_impossible': False}),
#  Prediction(uid='196', iid='870', r_ui=3.52986, est=3.342950904784014, details={'was_impossible': False}),
#  Prediction(uid='196', iid='39', r_ui=3.52986, est=3.2384340856631426, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1100', r_ui=3.52986, est=3.3476067791521293, details={'was_impossible': False}),
#  Prediction(uid='196', iid='820', r_ui=3.52986, est=2.8862272135918263, details={'was_impossible': False}),
#  Prediction(uid='196', iid='660', r_ui=3.52986, est=3.9201750368286215, details={'was_impossible': False}),
#  Prediction(uid='196', iid='120', r_ui=3.52986, est=2.1455299624652016, details={'was_impossible': False}),
# ...
#  Prediction(uid='196', iid='521', r_ui=3.52986, est=3.8784865200489977, details={'was_impossible': False}),
#  Prediction(uid='196', iid='728', r_ui=3.52986, est=3.0514447505489315, details={'was_impossible': False}),
#  Prediction(uid='196', iid='689', r_ui=3.52986, est=2.960851624422403, details={'was_impossible': False}),
#  Prediction(uid='196', iid='329', r_ui=3.52986, est=3.3189293122295704, details={'was_impossible': False}),
#  Prediction(uid='196', iid='859', r_ui=3.52986, est=3.2776610004734685, details={'was_impossible': False}),
#  Prediction(uid='196', iid='456', r_ui=3.52986, est=2.4792065245745825, details={'was_impossible': False}),
#  Prediction(uid='196', iid='791', r_ui=3.52986, est=2.817227444275899, details={'was_impossible': False}),
#  Prediction(uid='196', iid='159', r_ui=3.52986, est=3.193938477532975, details={'was_impossible': False}),
#  Prediction(uid='196', iid='489', r_ui=3.52986, est=3.9777681157118745, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1266', r_ui=3.52986, est=3.6954509081005624, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1416', r_ui=3.52986, est=3.1105513980473884, details={'was_impossible': False}),
#  Prediction(uid='196', iid='988', r_ui=3.52986, est=2.124907385764479, details={'was_impossible': False}),
#  Prediction(uid='196', iid='636', r_ui=3.52986, est=3.4322694077983167, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1411', r_ui=3.52986, est=2.6144475027167466, details={'was_impossible': False}),
#  Prediction(uid='196', iid='533', r_ui=3.52986, est=3.8298313253166203, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1394', r_ui=3.52986, est=3.582699963935712, details={'was_impossible': False}),
#  Prediction(uid='196', iid='819', r_ui=3.52986, est=2.7542759759905215, details={'was_impossible': False}),
#  Prediction(uid='196', iid='495', r_ui=3.52986, est=3.3879521550491276, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1093', r_ui=3.52986, est=3.0895177568812024, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1492', r_ui=3.52986, est=3.549520419403018, details={'was_impossible': False}),
#  Prediction(uid='196', iid='30', r_ui=3.52986, est=4.010893672384702, details={'was_impossible': False}),
#  Prediction(uid='196', iid='314', r_ui=3.52986, est=2.974394881074632, details={'was_impossible': False}),
#  Prediction(uid='196', iid='958', r_ui=3.52986, est=4.137475006073556, details={'was_impossible': False}),
#  Prediction(uid='196', iid='841', r_ui=3.52986, est=2.7022983868360315, details={'was_impossible': False}),
#  Prediction(uid='196', iid='838', r_ui=3.52986, est=3.4568795465106534, details={'was_impossible': False}),
#  Prediction(uid='196', iid='702', r_ui=3.52986, est=3.269168000805994, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1020', r_ui=3.52986, est=3.939502575119813, details={'was_impossible': False}),
#  Prediction(uid='196', iid='947', r_ui=3.52986, est=3.7316192766350413, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1000', r_ui=3.52986, est=3.1555775512802566, details={'was_impossible': False}),
#  Prediction(uid='196', iid='104', r_ui=3.52986, est=2.9599687184854107, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1322', r_ui=3.52986, est=2.863375783921551, details={'was_impossible': False}),
#  Prediction(uid='196', iid='622', r_ui=3.52986, est=3.478190280721415, details={'was_impossible': False}),
#  Prediction(uid='196', iid='481', r_ui=3.52986, est=4.254449606621572, details={'was_impossible': False}),
#  Prediction(uid='196', iid='532', r_ui=3.52986, est=3.58024692707576, details={'was_impossible': False}),
#  Prediction(uid='196', iid='915', r_ui=3.52986, est=3.4952776757583472, details={'was_impossible': False}),
#  Prediction(uid='196', iid='502', r_ui=3.52986, est=3.336067053647466, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1291', r_ui=3.52986, est=2.5319863192675167, details={'was_impossible': False}),
#  Prediction(uid='196', iid='330', r_ui=3.52986, est=3.008348188490315, details={'was_impossible': False}),
#  Prediction(uid='196', iid='802', r_ui=3.52986, est=2.9906947399743684, details={'was_impossible': False}),
#  Prediction(uid='196', iid='37', r_ui=3.52986, est=3.2161414298501034, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1025', r_ui=3.52986, est=2.872927229687302, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1364', r_ui=3.52986, est=3.354497695816483, details={'was_impossible': False}),
#  Prediction(uid='196', iid='266', r_ui=3.52986, est=2.7526304672616004, details={'was_impossible': False}),
#  Prediction(uid='196', iid='727', r_ui=3.52986, est=3.589498549030175, details={'was_impossible': False}),
#  Prediction(uid='196', iid='828', r_ui=3.52986, est=3.215431144068762, details={'was_impossible': False}),
#  Prediction(uid='196', iid='548', r_ui=3.52986, est=2.81675835487234, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1132', r_ui=3.52986, est=2.8130584428487757, details={'was_impossible': False}),
#  Prediction(uid='196', iid='993', r_ui=3.52986, est=3.597061924346166, details={'was_impossible': False}),
#  Prediction(uid='196', iid='136', r_ui=3.52986, est=3.900355577665919, details={'was_impossible': False}),
#  Prediction(uid='196', iid='996', r_ui=3.52986, est=2.9769689134475836, details={'was_impossible': False}),
#  Prediction(uid='196', iid='562', r_ui=3.52986, est=3.2047439865141985, details={'was_impossible': False}),
#  Prediction(uid='196', iid='653', r_ui=3.52986, est=3.9497892290982017, details={'was_impossible': False}),
#  Prediction(uid='196', iid='74', r_ui=3.52986, est=3.3616964501304123, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1493', r_ui=3.52986, est=3.066343184367308, details={'was_impossible': False}),
#  Prediction(uid='196', iid='45', r_ui=3.52986, est=4.147728576836339, details={'was_impossible': False}),
#  Prediction(uid='196', iid='867', r_ui=3.52986, est=3.7664329180867524, details={'was_impossible': False}),
#  Prediction(uid='196', iid='876', r_ui=3.52986, est=2.8342787686866715, details={'was_impossible': False}),
#  Prediction(uid='196', iid='158', r_ui=3.52986, est=2.6920889041874534, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1183', r_ui=3.52986, est=2.719778991773445, details={'was_impossible': False}),
#  Prediction(uid='196', iid='500', r_ui=3.52986, est=3.7045892630597574, details={'was_impossible': False}),
#  Prediction(uid='196', iid='610', r_ui=3.52986, est=3.716246366068338, details={'was_impossible': False}),
#  Prediction(uid='196', iid='887', r_ui=3.52986, est=3.6284442647712556, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1299', r_ui=3.52986, est=3.3236862268094156, details={'was_impossible': False}),
#  Prediction(uid='196', iid='918', r_ui=3.52986, est=3.35901888095855, details={'was_impossible': False}),
#  Prediction(uid='196', iid='41', r_ui=3.52986, est=3.3745605923404423, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1066', r_ui=3.52986, est=3.2496239396316295, details={'was_impossible': False}),
#  Prediction(uid='196', iid='336', r_ui=3.52986, est=2.4550594774121612, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1117', r_ui=3.52986, est=2.924742348117361, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1169', r_ui=3.52986, est=3.880807803897151, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1262', r_ui=3.52986, est=3.3134766849119597, details={'was_impossible': False}),
#  Prediction(uid='196', iid='348', r_ui=3.52986, est=3.1376372060802202, details={'was_impossible': False}),
#  Prediction(uid='196', iid='270', r_ui=3.52986, est=3.5686591676454165, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1053', r_ui=3.52986, est=3.2373706534514586, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1464', r_ui=3.52986, est=3.4075835282404965, details={'was_impossible': False}),
#  Prediction(uid='196', iid='374', r_ui=3.52986, est=2.791551525870631, details={'was_impossible': False}),
#  Prediction(uid='196', iid='621', r_ui=3.52986, est=3.1002078453224002, details={'was_impossible': False}),
#  Prediction(uid='196', iid='607', r_ui=3.52986, est=3.8212403884449606, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1030', r_ui=3.52986, est=2.6995393880672656, details={'was_impossible': False}),
#  Prediction(uid='196', iid='777', r_ui=3.52986, est=3.189429707272445, details={'was_impossible': False}),
#  Prediction(uid='196', iid='700', r_ui=3.52986, est=3.0599973569302783, details={'was_impossible': False}),
#  Prediction(uid='196', iid='297', r_ui=3.52986, est=4.109300565316855, details={'was_impossible': False}),
#  Prediction(uid='196', iid='925', r_ui=3.52986, est=3.5785765631521875, details={'was_impossible': False}),
#  Prediction(uid='196', iid='928', r_ui=3.52986, est=3.0187965811226163, details={'was_impossible': False}),
#  Prediction(uid='196', iid='394', r_ui=3.52986, est=3.2664143161118133, details={'was_impossible': False}),
#  Prediction(uid='196', iid='549', r_ui=3.52986, est=3.6467710625317604, details={'was_impossible': False}),
#  Prediction(uid='196', iid='999', r_ui=3.52986, est=3.320521292943724, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1471', r_ui=3.52986, est=2.8498789078584683, details={'was_impossible': False}),
#  Prediction(uid='196', iid='341', r_ui=3.52986, est=3.141331144921005, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1009', r_ui=3.52986, est=3.635672092665548, details={'was_impossible': False}),
#  Prediction(uid='196', iid='391', r_ui=3.52986, est=3.0222934726827773, details={'was_impossible': False}),
#  Prediction(uid='196', iid='467', r_ui=3.52986, est=3.6659585979391873, details={'was_impossible': False}),
#  Prediction(uid='196', iid='811', r_ui=3.52986, est=3.7887022333795817, details={'was_impossible': False}),
#  Prediction(uid='196', iid='805', r_ui=3.52986, est=3.630045636762771, details={'was_impossible': False}),
#  Prediction(uid='196', iid='519', r_ui=3.52986, est=3.8860613070328203, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1036', r_ui=3.52986, est=3.303523497968631, details={'was_impossible': False}),
#  Prediction(uid='196', iid='84', r_ui=3.52986, est=3.2640089919812607, details={'was_impossible': False}),
#  Prediction(uid='196', iid='894', r_ui=3.52986, est=2.3562226416116556, details={'was_impossible': False}),
#  Prediction(uid='196', iid='574', r_ui=3.52986, est=2.62518354284441, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1113', r_ui=3.52986, est=3.274957138448559, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1306', r_ui=3.52986, est=3.4430332498404255, details={'was_impossible': False}),
#  Prediction(uid='196', iid='638', r_ui=3.52986, est=3.816467964364031, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1314', r_ui=3.52986, est=2.804146350203435, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1131', r_ui=3.52986, est=3.88006338842586, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1069', r_ui=3.52986, est=3.387331893769802, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1084', r_ui=3.52986, est=3.859826268839943, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1407', r_ui=3.52986, est=2.345778812958081, details={'was_impossible': False}),
#  Prediction(uid='196', iid='878', r_ui=3.52986, est=3.0174367723503805, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1242', r_ui=3.52986, est=3.377293354380582, details={'was_impossible': False}),
#  Prediction(uid='196', iid='359', r_ui=3.52986, est=3.4127290418066747, details={'was_impossible': False}),
#  Prediction(uid='196', iid='579', r_ui=3.52986, est=2.871609263040369, details={'was_impossible': False}),
#  Prediction(uid='196', iid='884', r_ui=3.52986, est=3.6830295738716723, details={'was_impossible': False}),
#  Prediction(uid='196', iid='691', r_ui=3.52986, est=3.475674275777404, details={'was_impossible': False}),
#  Prediction(uid='196', iid='954', r_ui=3.52986, est=3.6296455810810624, details={'was_impossible': False}),
#  Prediction(uid='196', iid='261', r_ui=3.52986, est=2.566031753175959, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1112', r_ui=3.52986, est=2.8682934679133094, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1090', r_ui=3.52986, est=2.440064485384375, details={'was_impossible': False}),
#  Prediction(uid='196', iid='445', r_ui=3.52986, est=3.5508543895408096, details={'was_impossible': False}),
#  Prediction(uid='196', iid='635', r_ui=3.52986, est=2.750222705780886, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1135', r_ui=3.52986, est=3.141748096358257, details={'was_impossible': False}),
#  Prediction(uid='196', iid='76', r_ui=3.52986, est=3.4776102221013954, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1082', r_ui=3.52986, est=3.1142522983451193, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1215', r_ui=3.52986, est=2.236560724384219, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1328', r_ui=3.52986, est=3.486744408532965, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1013', r_ui=3.52986, est=2.3029478141604063, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1170', r_ui=3.52986, est=3.4822557618940677, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1265', r_ui=3.52986, est=2.824033585715496, details={'was_impossible': False}),
#  Prediction(uid='196', iid='735', r_ui=3.52986, est=3.9795038618319896, details={'was_impossible': False}),
#  Prediction(uid='196', iid='352', r_ui=3.52986, est=2.618827123604078, details={'was_impossible': False}),
#  Prediction(uid='196', iid='833', r_ui=3.52986, est=3.407573471514785, details={'was_impossible': False}),
#  Prediction(uid='196', iid='722', r_ui=3.52986, est=2.8069267870392443, details={'was_impossible': False}),
#  Prediction(uid='196', iid='434', r_ui=3.52986, est=3.9376336294870553, details={'was_impossible': False}),
#  Prediction(uid='196', iid='801', r_ui=3.52986, est=2.7512909189164203, details={'was_impossible': False}),
#  Prediction(uid='196', iid='224', r_ui=3.52986, est=3.7761038464087147, details={'was_impossible': False}),
#  Prediction(uid='196', iid='358', r_ui=3.52986, est=2.6005932583923363, details={'was_impossible': False}),
#  Prediction(uid='196', iid='966', r_ui=3.52986, est=4.00915185048437, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1351', r_ui=3.52986, est=3.370325321810867, details={'was_impossible': False}),
#  Prediction(uid='196', iid='675', r_ui=3.52986, est=3.6919235422618453, details={'was_impossible': False}),
#  Prediction(uid='196', iid='991', r_ui=3.52986, est=2.645471796663898, details={'was_impossible': False}),
#  Prediction(uid='196', iid='633', r_ui=3.52986, est=3.9333781166750286, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1102', r_ui=3.52986, est=3.2151969400679965, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1424', r_ui=3.52986, est=3.260580813781944, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1163', r_ui=3.52986, est=3.2363117131663386, details={'was_impossible': False}),
#  Prediction(uid='196', iid='1413', r_ui=3.52986, est=3.220118672673394, details={'was_impossible': False}),
#  Prediction(uid='196', iid='830', r_ui=3.52986, est=3.368466056287023, details={'was_impossible': False}),
#  Prediction(uid='196', iid='924', r_ui=3.52986, est=3.606868049957476, details={'was_impossible': False}),
#  Prediction(uid='196', iid='976', r_ui=3.52986, est=2.750229152319262, details={'was_impossible': False}),
#  Prediction(uid='196', iid='825', r_ui=3.52986, est=3.024792373312868, details={'was_impossible': False}),
#  Prediction(uid='196', iid='389', r_ui=3.52986, est=3.582279927095874, details={'was_impossible': False}),
#  ...]

# %%
reco_items = []
# Print the recommended items for each user
for uid, user_ratings in top_n.items():
    if uid == user_trial:
      reco_items = [iid for (iid, _) in user_ratings]
      print (uid, reco_items)
# Out:
# 6 ['114', '654', '647', '60', '603', '923', '615', '652', '656', '251']

# %%
[rid_to_name[str(i)] for i in reco_items]
# Out:
# ['Wallace & Gromit: The Best of Aardman Animation (1996)',
#  'Chinatown (1974)',
#  'Ran (1985)',
#  'Three Colors: Blue (1993)',
#  'Rear Window (1954)',
#  'Raise the Red Lantern (1991)',
#  '39 Steps, The (1935)',
#  'Rosencrantz and Guildenstern Are Dead (1990)',
#  'M (1931)',
#  'Shall We Dance? (1996)']

# %% [markdown]
# ### Precision-Recall Measures

# %%
def precision_recall_at_k(predictions, k=10, threshold=3.5):
    '''Return precision and recall at k metrics for each user.'''

    # First map the predictions to each user.
    user_est_true = defaultdict(list)
    for uid, _, true_r, est, _ in predictions:
        user_est_true[uid].append((est, true_r))

    precisions = dict()
    recalls = dict()
    for uid, user_ratings in user_est_true.items():

        # Sort user ratings by estimated value
        user_ratings.sort(key=lambda x: x[0], reverse=True)

        # Number of relevant items
        n_rel = sum((true_r >= threshold) for (_, true_r) in user_ratings)

        # Number of recommended items in top k
        n_rec_k = sum((est >= threshold) for (est, _) in user_ratings[:k])

        # Number of relevant and recommended items in top k
        n_rel_and_rec_k = sum(((true_r >= threshold) and (est >= threshold))
                              for (est, true_r) in user_ratings[:k])

        # Precision@K: Proportion of recommended items that are relevant
        precisions[uid] = n_rel_and_rec_k / n_rec_k if n_rec_k != 0 else 1

        # Recall@K: Proportion of relevant items that are recommended
        recalls[uid] = n_rel_and_rec_k / n_rel if n_rel != 0 else 1

    return precisions, recalls

# %%
kf = KFold(n_splits=5)
algo = SVD()

precs_list = []
recalls_list = []
for trainset, testset in kf.split(data):
    algo.fit(trainset)
    predictions = algo.test(testset)
    precisions, recalls = precision_recall_at_k(predictions, k=5, threshold=4)

    # Precision and recall can then be averaged over all users
    precs_list.append(sum(prec for prec in precisions.values()) / len(precisions))
    recalls_list.append(sum(rec for rec in recalls.values()) / len(recalls))

# %% [markdown]
# ### Precision Recall at *k = 5* using 5-fold cross validation

# %%
pd.DataFrame(np.array([precs_list, recalls_list]).T, columns = ['precision', 'recall'])
# Out:
#    precision    recall
# 0   0.880679  0.245855
# 1   0.870555  0.256419
# 2   0.877358  0.257587
# 3   0.867676  0.252710
# 4   0.872983  0.262353

# %% [markdown]
# ### Precision-Recall for varying *k*

# %%
precs_k_list, recs_k_list, ks = [], [], []
for i in range(2,21):
  
  ks.append(i)
  precisions, recalls = precision_recall_at_k(predictions, k=i, threshold=4) # threshold to ratings of 4

  prec_k = sum(prec for prec in precisions.values()) / len(precisions)
  rec_k = sum(rec for rec in recalls.values()) / len(recalls)
  
  precs_k_list.append(prec_k)
  recs_k_list.append(rec_k)

# %%
pd.DataFrame(np.array([ks, precs_k_list, recs_k_list]).T, columns = ['k', 'precision@k', 'recall@k']).set_index('k').plot(figsize = (20, 10))
# Out:
# <AxesSubplot:xlabel='k'>
